# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **Kyiv, Kyiv City, Ukraine**, or **Ukraine** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Kyiv, Kyiv City, Ukraine** to Ann Arbor, USA. In that case at least one source file must be about **Kyiv, Kyiv City, Ukraine**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Kyiv, Kyiv City, Ukraine** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = "drive/My Drive/applied_ds/applied_plotting/"

# %%
top10 = pd.read_csv(path + 'convertcsv.csv', sep="\t",skiprows=2, names= ["School","Place","TOP Ukraine", "Score", "Mean ZNO", "Students/Tests", "Passed %"]) 
top10
# Out:
#                                               School  ...  Passed %
# 0                                   Ліцей "Інтелект"  ...       100
# 1  Природничо-науковий ліцей №145 Печерського р-н...  ...       100
# 2  Технічний ліцей Національного технічного уніве...  ...       100
# 3  Український фізико-математичний ліцей Київсько...  ...       100
# 4  Український гуманітарний ліцей Київського наці...  ...       100
# 5          Гімназія №178 Солом’янського р-ну м.Києва  ...       100
# 6                              Ліцей "Наукова зміна"  ...       100
# 7                                Ліцей №208 м. Києва  ...       100
# 8  Києво-Печерський ліцей № 171 «Лідер» Печерсько...  ...       100
# 9                                 Ліцей №142 м.Києва  ...       100
#
# [10 rows x 7 columns]

# %%
all_schools19 = pd.read_csv(path + 'all_schools_2019.csv', sep="\t") 

# [a for a in list(all_schools['Назва']) ]

# %%
import re

# %%
# re.sub('м.Києва|м. Києва'', '', top10)
# [x.replace('м.Києва'|'м. Києва','') for x in top10]
# df.merge(all_schools, left_on='Назва навчального закладу', right_on='Назва')
all_schools[all_schools["Назва"] == 'Ліцей "Інтелект"']
# Out:
# Empty DataFrame
# Columns: [Назва, Тип, [100;120), [120;140), [140;160), [160;180), [180;200]]
# Index: []

# %%
all_schools19 = all_schools19.reset_index()

# %%
all_schools19.columns = ["School", "Type", "Number of students", "Not passed %", "[100;120)","[120;140)","[140;160)","[160;180)","[180;200]"]

# %%
all_schools19
# Out:
#                                                 School  ... [180;200]
# 0    Навчально-виховний комплекс Школа І-ІІ ступені...  ...     26,67
# 1    Авіакосмічний ліцей ім. І.Сікорського НАУ м.Києва  ...     37,89
# 2    Бізнес-коледж приватного вищого навчального за...  ...      5,00
# 3    Вечірня (змінна) школа №20 Солом'янського райо...  ...      0,00
# 4                    Вечірня (змінна) школа №3 м.Києва  ...      0,00
# ..                                                 ...  ...       ...
# 455  Школа ІІ - ІІІ ступенів №328 Оболонського райо...  ...      7,55
# 456  Школа ІІ-ІІІ ступенів №319 імені Валерія Лобан...  ...      0,00
# 457  Юридичний ліцей імені Ярослава Кондратьєва Нац...  ...      0,00
# 458                           інші категорії учасників  ...      5,78
# 459                                           Загалом:  ...       NaN
#
# [460 rows x 9 columns]

# %%
pd.merge(top10,all_schools19, on='School',how ="left")
# Out:
#                                               School  Place  ...  [160;180)  [180;200]
# 0                                   Ліцей "Інтелект"      1  ...      13,51      83,78
# 1  Природничо-науковий ліцей №145 Печерського р-н...      2  ...        NaN        NaN
# 2  Технічний ліцей Національного технічного уніве...      3  ...        NaN        NaN
# 3  Український фізико-математичний ліцей Київсько...      4  ...      12,94      87,06
# 4  Український гуманітарний ліцей Київського наці...      5  ...      45,45      36,36
# 5          Гімназія №178 Солом’янського р-ну м.Києва      6  ...        NaN        NaN
# 6                              Ліцей "Наукова зміна"      7  ...      32,86      41,43
# 7                                Ліцей №208 м. Києва      8  ...      16,46      74,68
# 8  Києво-Печерський ліцей № 171 «Лідер» Печерсько...      9  ...        NaN        NaN
# 9                                 Ліцей №142 м.Києва     10  ...      17,39      78,26
#
# [10 rows x 15 columns]

# %%
imp

# %% [markdown]
# CompositeRank	IT_CompositeRank	TotalRank	MedTotalRank	IT_Rank	UkrRank	MathRank	PhysRank	EngRank	HistRank	ChemRank	BioRank	AvgScore	MedScore	EOName	EOAreaFullName	Examinees	FailedExams	PassRate	TotalRank_D	MedTotalRank_D	IT_Rank_D	UkrRank_D	MathRank_D	PhysRank_D	EngRank_D	HistRank_D	ChemRank_D	BioRank_D	IT_AvgScore	UkrAvg	UkrMed	UkrN	HistAvg	HistMed	HistN	MathAvg	MathMed	MathN	PhysAvg	PhysMed	PhysN	ChemAvg	ChemMed	ChemN	BioAvg	BioMed	BioN	GeoAvg	GeoMed	GeoN	EngAvg	EngMed	EngN	FrAvg	FrMed	FrN	DeuAvg	DeuMed	DeuN	SpAvg	SpMed	SpN	EOTypeName	TerType	IsPrivate	StdDevScore	UkrStDev	HistStDev	MathStDev	PhysStDev	ChemStDev	BioStDev	GeoStDev	EngStDev	FrStDev	DeuStDev	SpStDev

# %%
top10["School"]
# Out:
# 0                                     Ліцей "Інтелект"
# 1    Природничо-науковий ліцей №145 Печерського р-н...
# 2    Технічний ліцей Національного технічного уніве...
# 3    Український фізико-математичний ліцей Київсько...
# 4    Український гуманітарний ліцей Київського наці...
# 5            Гімназія №178 Солом’янського р-ну м.Києва
# 6                                Ліцей "Наукова зміна"
# 7                                  Ліцей №208 м. Києва
# 8    Києво-Печерський ліцей № 171 «Лідер» Печерсько...
# 9                                   Ліцей №142 м.Києва
# Name: School, dtype: object

# %%
df[df["Назва навчального закладу"]=="Природничо-науковий ліцей №145 Печерського району м. Києва"]
# Out:
# Empty DataFrame
# Columns: [Назва навчального закладу, Місце, TOP, Рейт. бал, Бал ЗНО, Учнів / тестів, Склав (%)]
# Index: []

# %%
list(df["Назва навчального закладу"])
# Out:
# ['Ліцей "Інтелект"',
#  'Природничо-науковий ліцей №145 Печерського р-ну м. Києва',
#  'Технічний ліцей Національного технічного університету України "Київський політехнічний інститут" Солом’янського р-ну м.Києва',
#  'Український фізико-математичний ліцей Київського національного університету імені Т.Шевченка',
#  'Український гуманітарний ліцей Київського національного університету імені Тараса Шевченка',
#  'Гімназія №178 Солом’янського р-ну м.Києва',
#  'Ліцей "Наукова зміна"',
#  'Ліцей №208 м. Києва',
#  'Києво-Печерський ліцей № 171 «Лідер» Печерського р-ну м. Києва',
#  'Ліцей №142 м.Києва']

# %%
all_schools[all_schools["School"]=="Природничо-науковий ліцей №145 Печерського району м. Києва"]
top10 = list(df["Назва навчального закладу"])
df["School"] = [x.replace('району','р-ну') for x in top10]
df
# Out:
#                            Назва навчального закладу  ...                                             School
# 0                                   Ліцей "Інтелект"  ...                                   Ліцей "Інтелект"
# 1  Природничо-науковий ліцей №145 Печерського р-н...  ...  Природничо-науковий ліцей №145 Печерського р-н...
# 2  Технічний ліцей Національного технічного уніве...  ...  Технічний ліцей Національного технічного уніве...
# 3  Український фізико-математичний ліцей Київсько...  ...  Український фізико-математичний ліцей Київсько...
# 4  Український гуманітарний ліцей Київського наці...  ...  Український гуманітарний ліцей Київського наці...
# 5          Гімназія №178 Солом’янського р-ну м.Києва  ...          Гімназія №178 Солом’янського р-ну м.Києва
# 6                              Ліцей "Наукова зміна"  ...                              Ліцей "Наукова зміна"
# 7                                Ліцей №208 м. Києва  ...                                Ліцей №208 м. Києва
# 8  Києво-Печерський ліцей № 171 «Лідер» Печерсько...  ...  Києво-Печерський ліцей № 171 «Лідер» Печерсько...
# 9                                 Ліцей №142 м.Києва  ...                                 Ліцей №142 м.Києва
#
# [10 rows x 8 columns]

# %%
df = pd.read_csv(path + 'Odata2019MagFile.csv',sep=";") 
df
# Out:
#                                       OUTID  Birth  ... SPTAreaName SPTTerName
# 0      8f79c403-7700-11e9-9690-f4034343392c   1997  ...         NaN        NaN
# 1      7bfe2606-7700-11e9-9690-f4034343392c   1998  ...         NaN        NaN
# 2      b8eea907-7700-11e9-9690-f4034343392c   1995  ...         NaN        NaN
# 3      9cf8b822-7700-11e9-9690-f4034343392c   1998  ...         NaN        NaN
# 4      0935dc2b-7700-11e9-9690-f4034343392c   1998  ...         NaN        NaN
# ...                                     ...    ...  ...         ...        ...
# 65409  13ed41f3-85ff-11e9-9690-f4034343392c   1996  ...         NaN        NaN
# 65410  ca8524f6-85ff-11e9-9690-f4034343392c   1998  ...         NaN        NaN
# 65411  273ba6f6-85ff-11e9-9690-f4034343392c   1997  ...         NaN        NaN
# 65412  49efa8f6-85ff-11e9-9690-f4034343392c   1998  ...         NaN        NaN
# 65413  59c5e2fe-85ff-11e9-9690-f4034343392c   1994  ...         NaN        NaN
#
# [65414 rows x 55 columns]

# %%
lawayr = df.dropna(subset=['TBall100', 'LBall100'])
lawayr["TBall100"]= lawayr["TBall100"].astype(str) 
lawayr["TBall100"] = [float(str(x).replace(",", ".")) for x in list(lawayr["TBall100"])]

t_mean = lawayr[lawayr["TTestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['TBall100'].agg(['mean', 'count'])


lawayr["LBall100"]= lawayr["LBall100"].astype(str) 
lawayr["LBall100"] = [float(str(x).replace(",", ".")) for x in list(lawayr["LBall100"])]

l_mean = lawayr[lawayr["LTestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['LBall100'].agg(['mean', 'count'])


lawayr = lawayr.dropna(subset=['EBall100'])
lawayr["EBall100"]= lawayr["EBall100"].astype(str) 
lawayr["EBall100"] = [float(str(x).replace(",", ".")) for x in list(lawayr["EBall100"])]

e_mean = lawayr[lawayr["ETestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['EBall100'].agg(['mean', 'count'])

# %%
df = df.dropna(subset=['LBall100', 'LBall100'])
df["LBall100"]= df["LBall100"].astype(str) 
df["LBall100"] = [float(x.replace(",", ".")) for x in list(df["LBall100"])]

# df = df.fillna(method='ffill')
# df = df.dropna(subset=['TBall100', 'LBall100'])
# # df.set_index('EONAME').groupby(level = 0)['TBall100'].agg({'TBall100': np.min })
# print(list(df["TBall100"])[0])


# df[df["TTestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['TBall100'].agg({'TBall100': np.average })
# np.min(df[df["TBall100"]])
l_mean = df[df["LTestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['LBall100'].agg(['mean', 'count'])

# %%
df["EBall100"]= df["EBall100"].astype(str) 
df["EBall100"] = [float(x.replace(",", ".")) for x in list(df["EBall100"])]

df_e_mean = df[df["ETestStatus"] =="Зараховано"].set_index('EONAME').groupby(level = 0)['EBall100'].agg({ 'EBall100': np.average})
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   after removing the cwd from sys.path.

# %%
# df_e_mean = df_e_mean.sort_values('GEMean', ascending=False)[df_e_mean["count"] >50]
group = lawayr[lawayr["ETestStatus"] =="Зараховано"].set_index('EONAME')["EBall100"].groupby(level = 0).mean()
group
# Out:
# EONAME
# "Харківський економіко-правовий університет" у формі товариства з обмеженою відповідальністю                                              121.833333
# Інститут управління і права Національного юридичного університету імені Ярослава Мудрого                                                  120.642857
# Академія Державної пенітенціарної служби                                                                                                  114.075472
# Академія адвокатури України                                                                                                               136.108434
# Академія праці, соціальних відносин і туризму                                                                                             128.900000
#                                                                                                                                              ...
# Центральноукраїнський інститут Приватне акціонерне товариство "Вищий навчальний заклад "Міжрегіональна Академія управління персоналом"    125.000000
# Черкаський національний університет імені Богдана Хмельницького                                                                           132.447368
# Черкаський інститут пожежної безпеки імені Героїв Чорнобиля Національного університету цивільного захисту України                         116.625000
# Чернівецький національний університет імені Юрія Федьковича                                                                               130.514706
# Чорноморський національний університет імені Петра Могили                                                                                 131.900000
# Name: EBall100, Length: 140, dtype: float64

# %%
t_mean = t_mean.sort_values('mean', ascending=False)[t_mean["count"] >50]
t_mean
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                           mean  count
# EONAME
# Національний університет "Києво-Могилянська ака...  161.777778     99
# Київський національний університет імені Тараса...  150.252144    583
# Львівський національний університет імені Івана...  146.560976    410
# Національний юридичний університет імені Яросла...  144.648796   1287
# Національний технічний університет України "Киї...  144.153846     65
# Національний університет "Острозька академія"       140.681159     69
# Державний вищий навчальний заклад "Київський на...  140.343195    169
# Одеський національний університетт ім. І.І. Меч...  139.897727     88
# Університет митної справи та фінансів               139.015625     64
# Полтавський юридичний інститут Національного юр...  137.477419    155
# Черкаський національний університет імені Богда...  137.288462     52
# Дніпровський національний університет імені Оле...  137.238636     88
# Запорізький національний університет                136.926174    149
# Харківський національний університет імені В.Н....  136.500000     90
# Сумський державний університет                      136.123288    146
# Державний вищий навчальний заклад "Прикарпатськ...  136.022059    136
# Київський національний торговельно-економічний ...  135.688172    186
# Національний авіаційний університет                 135.683168    101
# Національний університет "Одеська юридична акад...  135.398475   1049
# Донецький національний університет імені Василя...  135.264957    117
# Київський університет права Національної академ...  135.057971     69
# Державний вищий навчальний заклад «Ужгородський...  135.043796    137
# Чернівецький національний університет імені Юрі...  134.512195    205
# Академія адвокатури України                         134.271845    103
# Університет державної фіскальної служби України     134.052632    380
# Національний транспортний університет               133.787500     80
# Херсонський державний університет                   133.244444     90
# Східноєвропейський національний університет іме...  133.104167     96
# Східноукраїнський національний університет імен...  132.603175     63
# Національний університет "Львівська політехніка"    132.567797    236
# Національний університет біоресурсів і природок...  132.472527     91
# Хмельницький університет управління та права        132.404255    141
# Маріупольський державний університет                131.274510     51
# Тернопільський національний економічний універс...  131.182390    159
# Донецький юридичний інститут МВС України            130.031915     94
# ПВНЗ "Міжнародний науково-технічний університет...  128.409836     61
# Національний університет водного господарства т...  127.973684    114
# Національна академія внутрішніх справ               127.806841    994
# Житомирський національний агроекологічний уніве...  127.313253     83
# Одеський державний університет внутрішніх справ     127.214559    261
# Вінницький національний аграрний університет        127.142857     63
# Вінницький торговельно-економічний інститут Киї...  126.764706     51
# Вищий навчальний заклад Укоопспілки "Полтавськи...  126.727273     55
# Львівський державний університет внутрішніх справ   126.277311    238
# Навчально-науковий інститут технологій Чернігів...  125.682927     82
# Академія Державної пенітенціарної служби            125.242105     95
# Харківський національний університет внутрішніх...  124.991045    335
# Дніпропетровський державний університет внутріш...  124.417127    362
# Державний університет інфраструктури та технологій  123.418182     55
# Запорізький національний технічний університет      122.812500     80
# Відкритий міжнародний університет розвитку люди...  122.584906     53
# Сумська філія Харківського національного універ...  121.223881     67

# %%
l_mean = l_mean.sort_values('mean', ascending=False)[l_mean["count"] >50]
l_mean
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                           mean  count
# EONAME
# Національний університет "Києво-Могилянська ака...  156.958763     97
# Львівський національний університет імені Івана...  152.487437    398
# Київський національний університет імені Тараса...  146.761733    554
# Національний юридичний університет імені Яросла...  144.571314   1248
# Національний університет "Острозька академія"       141.723684     76
# Чернівецький національний університет імені Юрі...  137.937198    207
# Донецький національний університет імені Василя...  137.704762    105
# Полтавський юридичний інститут Національного юр...  137.608974    156
# Державний вищий навчальний заклад «Ужгородський...  135.338583    127
# Національний технічний університет України "Киї...  134.800000     60
# Харківський національний університет імені В.Н....  134.512500     80
# Державний вищий навчальний заклад "Прикарпатськ...  134.309735    113
# Східноєвропейський національний університет іме...  133.583333     84
# Національний університет "Одеська юридична акад...  133.400000    905
# Державний вищий навчальний заклад "Київський на...  133.320513    156
# Дніпровський національний університет імені Оле...  133.319444     72
# Одеський національний університетт ім. І.І. Меч...  132.387500     80
# Хмельницький університет управління та права        131.358779    131
# Академія адвокатури України                         131.040816     98
# Університет митної справи та фінансів               130.644068     59
# Навчально-науковий інститут технологій Чернігів...  129.794118     68
# Київський національний торговельно-економічний ...  129.142857    147
# Запорізький національний університет                129.083333    132
# Університет державної фіскальної служби України     128.378788    330
# Національний авіаційний університет                 128.376623     77
# Сумський державний університет                      128.076271    118
# Національний університет "Львівська політехніка"    127.636816    201
# Житомирський національний агроекологічний уніве...  127.173913     69
# Тернопільський національний економічний універс...  127.128000    125
# Херсонський державний університет                   125.333333     75
# Національний транспортний університет               125.016949     59
# Донецький юридичний інститут МВС України            124.000000     74
# Київський університет права Національної академ...  123.953846     65
# Національний університет біоресурсів і природок...  123.714286     77
# Львівський державний університет внутрішніх справ   123.548223    197
# Національний університет водного господарства т...  123.311111     90
# Національна академія внутрішніх справ               123.282878    806
# Вищий навчальний заклад Укоопспілки "Полтавськи...  122.500000     54
# Запорізький національний технічний університет      122.473684     57
# Дніпропетровський державний університет внутріш...  121.811024    254
# Вінницький національний аграрний університет        121.145455     55
# Харківський національний університет внутрішніх...  121.061776    259
# Академія Державної пенітенціарної служби            120.486842     76
# ПВНЗ "Міжнародний науково-технічний університет...  120.175439     57
# Одеський державний університет внутрішніх справ     119.380282    213
# Сумська філія Харківського національного універ...  119.116667     60

# %%
e_mean = e_mean.sort_values('mean', ascending=False)[e_mean["count"] >50]
e_mean
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                           mean  count
# EONAME
# Національний університет "Києво-Могилянська ака...  177.397959     98
# Київський національний університет імені Тараса...  165.242938    531
# Львівський національний університет імені Івана...  156.604396    364
# Національний технічний університет України "Киї...  147.596491     57
# Національний авіаційний університет                 145.193182     88
# Національний університет "Острозька академія"       145.142857     56
# Державний вищий навчальний заклад "Київський на...  144.021277    141
# Національний юридичний університет імені Яросла...  143.340502   1116
# Дніпровський національний університет імені Оле...  141.626667     75
# Харківський національний університет імені В.Н....  141.068493     73
# Одеський національний університетт ім. І.І. Меч...  139.051948     77
# Київський національний торговельно-економічний ...  139.040816    147
# Державний вищий навчальний заклад «Ужгородський...  138.745283    106
# Університет митної справи та фінансів               137.288136     59
# Національний університет "Одеська юридична акад...  136.989486    856
# Київський університет права Національної академ...  136.846154     52
# Державний вищий навчальний заклад "Прикарпатськ...  136.117021     94
# Академія адвокатури України                         136.108434     83
# Хмельницький університет управління та права        135.724490     98
# Полтавський юридичний інститут Національного юр...  134.983193    119
# Східноєвропейський національний університет іме...  133.897059     68
# Тернопільський національний економічний універс...  132.324074    108
# Національний університет "Львівська політехніка"    131.284091    176
# Національний університет біоресурсів і природок...  130.719298     57
# Чернівецький національний університет імені Юрі...  130.514706    136
# Донецький національний університет імені Василя...  129.320988     81
# Запорізький національний університет                128.990566    106
# Національний транспортний університет               128.594595     74
# Сумський державний університет                      128.225806     93
# Університет державної фіскальної служби України     125.049242    264
# Національний університет водного господарства т...  123.892308     65
# Національна академія внутрішніх справ               122.657686    631
# Херсонський державний університет                   122.000000     53
# Донецький юридичний інститут МВС України            121.440678     59
# Дніпропетровський державний університет внутріш...  120.268041    194
# Харківський національний університет внутрішніх...  119.571429    196
# Львівський державний університет внутрішніх справ   117.141791    134
# Одеський державний університет внутрішніх справ     116.967742    155
# Академія Державної пенітенціарної служби            114.075472     53

# %%
e_mean.merge(df_e_mean, how="left")
# Out:
#            mean  count
# 0    121.833333      6
# 1    120.642857     14
# 2    114.075472     53
# 3    136.108434     83
# 4    128.900000     20
# ..          ...    ...
# 135  125.000000      4
# 136  132.447368     38
# 137  116.625000     16
# 138  130.514706    136
# 139  131.900000     40
#
# [140 rows x 2 columns]

# %%
print(df[df["TTest"] =="ТЗНПК"].shape)
print(df[df["LTest"] =="Право"].shape)
english_set = df.dropna(subset=['ETest'])
print(english_set[english_set["TTest"] =="ТЗНПК"].shape)
print(english_set[english_set["TTest"] !="ТЗНПК"].shape)
# Out:
# (16277, 55)
# (16277, 55)
# (15555, 55)
# (47271, 55)

# %%
english_set[english_set["ETestStatus"] =="Зараховано"].shape
# Out:
# (36351, 55)

# %%
english_set[english_set["TTest"] =="ТЗНПК"].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-2d5971672bd7> in <module>()
# ----> 1 english_set[english_set["TTest"] =="ТЗНПК"].shape()
#
# TypeError: 'tuple' object is not callable

# %%
# english for lawayrs
passed = english_set[english_set["ETestStatus"] =="Зараховано"][english_set["TTest"] =="ТЗНПК"]
passed_range = passed.groupby("EBall100")["EBall100"].count()
y_pos = passed_range.index

plt.bar(list(y_pos), list(passed_range), align='center', alpha=0.5)

plt.ylabel('Students')
plt.title('Results')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
# english for others
passed = english_set[english_set["ETestStatus"] =="Зараховано"][english_set["TTest"] !="ТЗНПК"]
passed_range = passed.groupby("EBall100")["EBall100"].count()
y_pos = passed_range.index

plt.bar(list(y_pos), list(passed_range), align='center', alpha=0.5)

plt.ylabel('Students')
plt.title('Results')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
passed = english_set[english_set["ETestStatus"] =="Зараховано"][english_set["EORegName"]	=="м.Київ"][english_set["TTest"] !="ТЗНПК"]
passed_range = passed.groupby("EBall100")["EBall100"].count()
y_pos = passed_range.index

plt.bar(list(y_pos), list(passed_range), align='center', alpha=0.5)

plt.ylabel('Students')
plt.title('Results')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
axs = [ax1,ax2]
english_kyiv = english_set[english_set["ETestStatus"] =="Зараховано"][english_set["EORegName"]	=="м.Київ"]
l_passed_kyiv = english_kyiv[english_kyiv["TTest"] =="ТЗНПК"].groupby("EBall100")["EBall100"].count()
others_passed_kyiv = english_kyiv[english_kyiv["TTest"] !="ТЗНПК"].groupby("EBall100")["EBall100"].count()


ax1.bar(list(l_passed_kyiv.index), list(l_passed_kyiv), align='center', color ="red", alpha=0.2)
ax2.bar(list(others_passed_kyiv.index), list(others_passed_kyiv), align='center', alpha=0.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <BarContainer object of 31 artists>

# %%
# ttest 
passed = df[df["TTestStatus"] =="Зараховано"][df["TTest"] =="ТЗНПК"]
passed_range = passed.groupby("TBall100")["TBall100"].count()
y_pos = passed_range.index

plt.bar(list(y_pos), list(passed_range), align='center', color="red", alpha=0.5)

plt.ylabel('Students')
plt.title('Results')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# low
passed = df[df["LTestStatus"] =="Зараховано"][df["TTest"] =="ТЗНПК"]
passed_range = passed.groupby("LBall100")["LBall100"].count()
y_pos = passed_range.index

plt.bar(list(y_pos), list(passed_range), align='center', color="red", alpha=0.5)

plt.ylabel('Students')
plt.title('Results')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
